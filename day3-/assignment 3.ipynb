# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1=np.cos(df)

# %%
df2=np.sin(df)

# %%
plt.plot(df,df1)

# %%
plt.plot(df1,df2)
plt.title("diabetes")
plt.xlabel("level1")
plt.ylabel("level2")
# Out:
# Text(0, 0.5, 'level2')

# %%
plt.plot(df1,df2)
plt.title("diabetes")
plt.xlabel("level1")
plt.ylabel("level2")
plt.show()

# %%
a3=np.linspace(-10,10,20)
a4=a3**2
plt.plot(a3,a4,"r+",linewidth=2,markersize=10)

# %%
sns.scatterplot(x=df1['Glucose'],y=df1['BloodPressure'],hue=df1['Age'])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='BloodPressure'>

# %%
sns.pairplot(df1,hue='Age',size=3)
# Out:
# C:\Users\bujji\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.hist(df1['Age'],bins=30,rwidth=0.5)
# Out:
# (array([145.,  15.,  20.,  32.,  13.,   5.,  66.,  41.,  13.,  18.,  32.,
#           2.,   8.,  16.,  17.,   4.,   7.,  21.,   0.,  17.,   1.,  47.,
#          15.,  13.,  34.,   4.,  28.,  19.,  29.,  86.]),
#  array([-9.99960826e-01, -9.33300689e-01, -8.66640551e-01, -7.99980413e-01,
#         -7.33320275e-01, -6.66660137e-01, -5.99999999e-01, -5.33339862e-01,
#         -4.66679724e-01, -4.00019586e-01, -3.33359448e-01, -2.66699310e-01,
#         -2.00039172e-01, -1.33379035e-01, -6.67188967e-02, -5.87588735e-05,
#          6.66013790e-02,  1.33261517e-01,  1.99921655e-01,  2.66581792e-01,
#          3.33241930e-01,  3.99902068e-01,  4.66562206e-01,  5.33222344e-01,
#          5.99882482e-01,  6.66542619e-01,  7.33202757e-01,  7.99862895e-01,
#          8.66523033e-01,  9.33183171e-01,  9.99843309e-01]),
#  <BarContainer object of 30 artists>)

# %%
sns.boxplot(df1['Age'],orient='h')
# Out:
# C:\Users\bujji\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>
